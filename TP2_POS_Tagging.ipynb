# %% [markdown]
# # TP2 - POS Tagging com BERT
#
# **Disciplina:** Processamento de Linguagem Natural
# **Aluno:** Caio Santana Trigueiro
# **Matrícula:** 2022043310
# **Data:** Novembro de 2025
#
# ---
#
# ## 📋 Objetivo
#
# Este trabalho prático tem como objetivo estudar e implementar um modelo de **POS Tagging** (Part-of-Speech Tagging), que consiste em classificar a classe gramatical de cada palavra em um texto. Utilizaremos Transformers pré-treinados, especificamente o modelo **BERT**, para realizar esta tarefa.
#
# ## 📊 Dataset
#
# - **Fonte:** [batterydata/pos_tagging](https://huggingface.co/datasets/batterydata/pos_tagging)
# - **Tipo:** Dataset de etiquetagem gramatical
# - **Splits:** Treino e Teste
#
# ## 🎯 Metodologia
#
# 1. **Exploração dos Dados:** Análise inicial do dataset
# 2. **Preprocessamento:** Preparação dos dados para o modelo
# 3. **Modelagem:** Fine-tuning do BERT para token classification
# 4. **Avaliação:** Cálculo de métricas de precisão
# 5. **Análise:** Discussão dos resultados por classe gramatical

# %% [markdown]
# ## 1. Configuração Inicial
#
# Importação das bibliotecas necessárias e configuração do ambiente.

# %%
# Imports básicos
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.auto import tqdm
import warnings
warnings.filterwarnings('ignore')

# Transformers e Datasets
from transformers import (
    AutoTokenizer, 
    AutoModelForTokenClassification,
    TrainingArguments, 
    Trainer,
    DataCollatorForTokenClassification
)
from datasets import load_dataset

# Métricas
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import torch

# Configuração
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# Verificar disponibilidade de GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Dispositivo utilizado: {device}")

# %% [markdown]
# ## 2. Carregamento e Exploração dos Dados
#
# Vamos carregar o dataset e realizar uma análise exploratória para entender sua estrutura.

# %%
# Carregar dataset do Hugging Face
print("Carregando dataset...")
dataset = load_dataset("batterydata/pos_tagging")

# Visualizar estrutura
print("\n=== Estrutura do Dataset ===")
print(dataset)

# %%
# Examinar um exemplo
print("\n=== Exemplo do conjunto de treino ===")
exemplo = dataset['train'][0]
for key, value in exemplo.items():
    print(f"{key}: {value}")

# %% [markdown]
# ### 2.1 Análise Estatística
#
# Vamos explorar as estatísticas básicas do dataset.

# %%
# Estatísticas básicas
print("=== Estatísticas do Dataset ===")
print(f"Número de exemplos de treino: {len(dataset['train'])}")
print(f"Número de exemplos de teste: {len(dataset['test'])}")

# Analisar distribuição de tags
# (Código será completado após verificar a estrutura exata do dataset)

# %% [markdown]
# ### 2.2 Classes Gramaticais (POS Tags)
#
# Análise das classes gramaticais presentes no dataset.

# %%
# Extrair informações sobre as classes
# (Será completado após análise do dataset)

# %% [markdown]
# ## 3. Preprocessamento
#
# Preparação dos dados para treinamento do modelo BERT.

# %%
# Inicializar tokenizer
# (Será implementado após exploração do dataset)

# %% [markdown]
# ## 4. Modelo BERT para POS Tagging
#
# Configuração e treinamento do modelo.

# %%
# Configuração do modelo
# (Será implementado)

# %% [markdown]
# ## 5. Avaliação
#
# Avaliação do modelo no conjunto de teste.

# %%
# Avaliação
# (Será implementado)

# %% [markdown]
# ## 6. Análise de Resultados
#
# ### 6.1 Métricas Globais
#
# Análise das métricas gerais do modelo.

# %%
# Métricas globais
# (Será implementado)

# %% [markdown]
# ### 6.2 Análise por Classe Gramatical
#
# Identificação das classes com melhor e pior performance.

# %%
# Análise por classe
# (Será implementado)

# %% [markdown]
# ## 7. Conclusões
#
# Discussão dos resultados e insights obtidos.
#
# **Principais observações:**
# - [A ser completado após análise]
#
# **Classes com melhor performance:**
# - [A ser completado]
#
# **Classes com pior performance:**
# - [A ser completado]
#
# **Possíveis melhorias:**
# - [A ser completado]

# %% [markdown]
# ## 📚 Referências
#
# - Devlin, J., et al. (2018). BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding.
# - Hugging Face Transformers Documentation: https://huggingface.co/docs/transformers
# - Dataset: https://huggingface.co/datasets/batterydata/pos_tagging
